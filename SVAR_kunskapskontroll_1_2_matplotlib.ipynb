# %% [markdown]
# # Matplotlib
# Read the tutorials: https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
# The Object Oriented approach or the Pyplot/Matplot approach. The OO-approach is the recommended one, atleast for bigger projects.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
# Figure is the canvas where everything goes on.
# Axes are the objects on the canvas i.e Titles, data points, labels etc
# Axis are the actual x,y and sometimes z axis. You can set different tick and ticklabels depending on the measurements you want.
# Artist is basically everything you render on the Figure.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
# The expected input data type is numpy.array or objects that can be converted to numpy.asarray

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
# Object Oriented Plot

x = np.linspace(-4, 4, 100)

fig, ax = plt.subplots(figsize=(4,4))
ax.plot(x, x**2, label='Squared')
ax.set(xlabel='X-axis', ylabel='Y-axis', title='Object Oriented Plot')
ax.legend()

# Pyplot

plt.figure(figsize=(4,4))
plt.plot(x, x**2, label='Squared')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Pyplot')
plt.legend()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# Creating a figure with 2 axes
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))

# Scatter plot
ax1.scatter(random_data_x, random_data_y)
ax1.set(xlabel='X-axis', ylabel='Y-axis', title='Scatter Plot')
ax1.plot(x, y, color = 'red')   # Not sure if this was supposed to be included but I did it anyways.


# Bar plot
ax2.bar(names, values)
ax2.set(xlabel='Fruits', ylabel='Quantity', title='Bar Plot')
# Out:
# [Text(0.5, 0, 'Fruits'), Text(0, 0.5, 'Quantity'), Text(0.5, 1.0, 'Bar Plot')]
